# %%
import nsfg
df = nsfg.ReadFemPreg()
df
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# 5           6         1        NaN        NaN       NaN       NaN       6.0
# 6           6         2        NaN        NaN       NaN       NaN       6.0
# 7           6         3        NaN        NaN       NaN       NaN       6.0
# 8           7         1        NaN        NaN       NaN       NaN       5.0
# 9           7         2        NaN        NaN       NaN       NaN       5.0
# 10         12         1        NaN        NaN       NaN       NaN       5.0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['caseid', 'pregordr', 'howpreg_n', 'howpreg_p', 'moscurrp', 'nowprgdk',
#        'pregend1', 'pregend2', 'nbrnaliv', 'multbrth',
#        ...
#        'laborfor_i', 'religion_i', 'metro_i', 'basewgt', 'adj_mod_basewgt',
#        'finalwgt', 'secu_p', 'sest', 'cmintvw', 'totalwgt_lb'],
#       dtype='object', length=244)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=13593, step=1)

# %%
max(df['pregordr'])
# Out:
# 19

# %%
df[df['pregordr']>10]
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 1319     1169        11        NaN        NaN       NaN       NaN       6.0
# 1789     1597        11        NaN        NaN       NaN       NaN       3.0
# 1790     1597        12        NaN        NaN       NaN       NaN       5.0
# 2495     2195        11        NaN        NaN       NaN       NaN       6.0
# 2496     2195        12        NaN        NaN       NaN       NaN       3.0
# 4754     4246        11        NaN        NaN       NaN       NaN       6.0
# 5769     5272        11        NaN        NaN       NaN       NaN       5.0
# 5770     5272        12        NaN        NaN       NaN       NaN       2.0
# 5771     5272        13        NaN        NaN       NaN       NaN       1.0
# 5772     5272        14        NaN        NaN       NaN       NaN       1.0
# 6954     6297        11        NaN        NaN       NaN       NaN       6.0
# ...

# %%
df['pregordr']
# Out:
# 0        1
# 1        2
# 2        1
# 3        2
# 4        3
# 5        1
# 6        2
# 7        3
# 8        1
# 9        2
# 10       1
# 11       1
# 12       2
# 13       3
# 14       1
# 15       2
# 16       3
# 17       1
# 18       2
# 19       1
# 20       2
# 21       1
# 22       2
# 23       1
# 24       2
# 25       3
# 26       1
# 27       1
# 28       2
# 29       3
#         ..
# 13563    2
# 13564    3
# 13565    1
# 13566    1
# 13567    1
# 13568    2
# 13569    1
# 13570    2
# 13571    3
# 13572    4
# 13573    1
# 13574    2
# 13575    1
# 13576    1
# 13577    2
# 13578    1
# 13579    2
# 13580    1
# 13581    2
# 13582    3
# 13583    1
# 13584    2
# 13585    1
# 13586    2
# 13587    3
# 13588    1
# 13589    2
# 13590    3
# 13591    4
# 13592    5
# Name: pregordr, Length: 13593, dtype: int64

# %%
max(df['agepreg'])
# Out:
# 44.079999999999998

# %%
min(df['agepreg'])
# Out:
# 10.33

# %%
import pandas as pd
import numpy as np

# %%
df.agepreg.idxmin()
# Out:
# 10751

# %%
df.iloc[10751,:]
# Out:
# caseid              9899.000000
# pregordr               1.000000
# howpreg_n                   NaN
# howpreg_p                   NaN
# moscurrp                    NaN
# nowprgdk                    NaN
# pregend1               3.000000
# pregend2                    NaN
# nbrnaliv                    NaN
# multbrth                    NaN
# cmotpreg            1051.000000
# prgoutcome             2.000000
# cmprgend            1051.000000
# flgdkmo1               1.000000
# cmprgbeg            1046.000000
# ageatend              15.000000
# hpageend              32.000000
# gestasun_m             0.000000
# gestasun_w            20.000000
# wksgest               20.000000
# mosgest                5.000000
# dk1gest                     NaN
# dk2gest                     NaN
# dk3gest                     NaN
# bpa_bdscheck1               NaN
# bpa_bdscheck2               NaN
# bpa_bdscheck3               NaN
# babysex                     NaN
# birthwgt_lb                 NaN
# ...

# %%
for index, caseid in df.caseid.iteritems():
    print(index, caseid)
# Out:
# 0 1
# 1 1
# 2 2
# 3 2
# 4 2
# 5 6
# 6 6
# 7 6
# 8 7
# 9 7
# 10 12
# 11 14
# 12 14
# 13 14
# 14 15
# 15 15
# 16 15
# 17 18
# 18 18
# 19 21
# 20 21
# 21 23
# 22 23
# 23 24
# 24 24
# 25 24
# 26 28
# 27 31
# 28 31
# 29 31
# 30 36
# 31 36
# 32 38
# 33 38
# 34 38
# 35 39
# 36 39
# 37 44
# 38 44
# 39 44
# 40 44
# 41 45
# 42 46
# 43 46
# 44 49
# 45 49
# 46 49
# 47 49
# 48 51
# 49 51
# 50 51
# 51 52
# 52 57
# 53 57
# 54 57
# 55 60
# 56 60
# 57 63
# 58 63
# 59 63
# 60 69
# 61 70
# 62 70
# 63 70
# 64 70
# 65 71
# 66 72
# 67 72
# 68 73
# 69 73
# 70 77
# 71 77
# 72 80
# 73 80
# 74 80
# 75 80
# 76 80
# 77 81
# 78 86
# 79 86
# 80 86
# 81 90
# 82 90
# 83 91
# 84 91
# 85 91
# 86 91
# 87 91
# 88 91
# 89 91
# 90 92
# 91 92
# 92 92
# 93 95
# 94 95
# 95 101
# 96 101
# 97 106
# 98 106
# 99 106
# 100 114
# 101 115
# 102 116
# 103 116
# 104 118
# 105 118
# 106 118
# 107 119
# 108 119
# 109 123
# 110 123
# 111 129
# 112 132
# 113 132
# 114 135
# 115 138
# 116 139
# 117 139
# 118 142
# 119 142
# 120 142
# ...

# %%
import collections
help(collections.defaultdict)
# Out:
# Help on class defaultdict in module collections:
#
# class defaultdict(builtins.dict)
#  |  defaultdict(default_factory[, ...]) --> dict with default factory
#  |
#  |  The default factory is called without arguments to produce
#  |  a new value when a key is not present, in __getitem__ only.
#  |  A defaultdict compares equal to a dict with the same items.
#  |  All remaining arguments are treated the same as if they were
#  |  passed to the dict constructor, including keyword arguments.
#  |
#  |  Method resolution order:
#  |      defaultdict
#  |      builtins.dict
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __copy__(...)
#  |      D.copy() -> a shallow copy of D.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __missing__(...)
# ...

# %%
ddico = collections.defaultdict(list)

# %%
ddico['key1'] = 'value1'
print(ddico)
# Out:
# defaultdict(<class 'list'>, {'key1': 'value1'})

# %%
ddico.__getitem__('key3')
# Out:
# []

# %%
print(ddico)
# Out:
# defaultdict(<class 'list'>, {'key1': 'value1', 'key3': []})

# %%
dico = dict()

# %%
dico['key1'] = 'value1'
print(dico)
# Out:
# {'key1': 'value1'}

# %%
dico.get('key3')

# %%
print(dico)
# Out:
# {'key1': 'value1'}
